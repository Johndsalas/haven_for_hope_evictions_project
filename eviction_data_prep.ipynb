# %%
import pandas as pd
from thefuzz import fuzz

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Readin and Initial Overview of Data

# %%
df = pd.read_excel('evictions_2023.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16657 entries, 0 to 16656
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   JP PRECINCT            16657 non-null  object
#  1   CaseNumber             16657 non-null  object
#  2   CaseFileDate           16657 non-null  datetime64[ns]
#  3   CORP                   16657 non-null  object
#  4   Plaintiff              16657 non-null  object
#  5   PERSON_ALIAS_ID        16657 non-null  int64
#  6   PlaintiffPhone         16657 non-null  object
#  7   PlaintiffAddress       16657 non-null  object
#  8   Pl_City                16657 non-null  object
#  9   Pl_State               16657 non-null  object
#  10  Pl_Zip                 16657 non-null  object
#  11  DefendantAddress       16028 non-null  object
#  12  Unit Number            8116 non-null   object
#  13  CITY_NAME              16028 non-null  object
#  14  STATE_CD               16028 non-null  object
#  15  POSTAL_CD              16028 non-null  object
#  16  Defendant              16657 non-null  object
#  17  Def_Phone              16657 non-null  object
#  18  CaseStatusDescription  16657 non-null  object
#  19  JUDGMENT_DT            16657 non-null  datetime64[ns]
#  20  Judgment               16657 non-null  object
#  21  Disposition            16657 non-null  object
#  22  DispositionDate        16657 non-null  datetime64[ns]
#  23  DISP_AMT               15317 non-null  float64
#  24  CASE_TYP_DESC          16657 non-null  object
# dtypes: datetime64[ns](3), float64(1), int64(1), object(20)
# memory usage: 3.2+ MB

# %%
og_data = df.shape[0]
print(f'Original Dataframe Length: {og_data}')
# Out:
# Original Dataframe Length: 16657

# %% [markdown]
# ## Get and Rename Relevant Columns

# %%
for col in df.columns:
    
    print(col)
# Out:
# JP PRECINCT
# CaseNumber
# CaseFileDate
# CORP
# Plaintiff
# PERSON_ALIAS_ID
# PlaintiffPhone
# PlaintiffAddress
# Pl_City
# Pl_State
# Pl_Zip
# DefendantAddress
# Unit Number
# CITY_NAME
# STATE_CD
# POSTAL_CD
# Defendant
# Def_Phone
# CaseStatusDescription
# JUDGMENT_DT
# Judgment
# Disposition
# DispositionDate
# DISP_AMT
# CASE_TYP_DESC

# %%
# get relevant columns and rename for clarity
df = df[['CaseNumber',        # used to distinguish unique cases
         'CaseFileDate',      # used for case date
         'JUDGMENT_DT',       # used for date case was ruled on
         'DispositionDate',   # used for date of disposition
         'CITY_NAME',         # used for city location
         'POSTAL_CD',         # used for zip code
         'Disposition',        # used to determine if case was dismissed
         ]]   

df = df.rename(columns={'CaseNumber'      : 'case_number',
                        'CaseFileDate'    : 'file_date',
                        'JUDGMENT_DT'     : 'judgement_date',
                        'DispositionDate' : 'disposition_date',
                        'CITY_NAME'       : 'city',
                        'POSTAL_CD'       : 'zip_code',
                        'Disposition'     : 'disposition'})

df.head(15)
# Out:
#    case_number  file_date judgement_date disposition_date         city  \
# 0   11E2102330 2021-12-13     2024-09-17       2024-09-17  SAN ANTONIO
# 1   11E2301639 2023-05-10     2024-05-01       2024-05-01  SAN ANTONIO
# 2   11E2303045 2023-08-16     2024-01-11       2023-12-08  San Antonio
# 3   11E2303045 2023-08-16     2024-01-11       2023-12-08  San Antonio
# 4   11E2303297 2023-08-30     2024-02-08       2024-02-08  San Antonio
# 5   11E2303925 2023-10-09     2024-01-11       2024-01-11  San Antonio
# 6   11E2304048 2023-10-17     2024-01-04       2024-01-04  San Antonio
# 7   11E2304072 2023-10-18     2024-07-09       2024-07-09  SAN ANTONIO
# 8   11E2304114 2023-10-19     2024-01-11       2024-01-11  SAN ANTONIO
# 9   11E2304258 2023-10-26     2024-06-18       2024-06-18  SAN ANTONIO
# 10  11E2304278 2023-10-27     2024-01-04       2024-01-04  SAN ANTONIO
# 11  11E2304289 2023-10-30     2024-01-23       2024-01-23  SAN ANTONIO
# 12  11E2304298 2023-10-30     2024-02-20       2024-02-20  SAN ANTONIO
# 13  11E2304327 2023-11-01     2024-01-04       2024-01-04  SAN ANTONIO
# 14  11E2304368 2023-11-03     2024-01-04       2024-01-04  SAN ANTONIO
#
#       zip_code                   disposition
# 0        78221  Judgment for Plaintiff (OCA)
# 1        78227        Agreed Judgments (OCA)
# 2        78214                     Dismissed
# 3        78214                     Dismissed
# 4        78251       Default Judgments (OCA)
# 5   78253-4301  Judgment for Plaintiff (OCA)
# 6        78226  Judgment for Plaintiff (OCA)
# 7        78221   Take Nothing Judgment (OCA)
# 8        78221  Judgment for Plaintiff (OCA)
# 9        78214  Judgment for Plaintiff (OCA)
# 10       78211       Default Judgments (OCA)
# 11       78221  Judgment for Plaintiff (OCA)
# 12       78245  Judgment for Plaintiff (OCA)
# 13       78221  Judgment for Plaintiff (OCA)
# 14       78253       Default Judgments (OCA)

# %% [markdown]
# ## Getting Relevant City Values
# * Used the fuzz to adjust for misspellings and abreviations of San Antonio
# * Data includes surrounding areas of San Antonio it is unclear if it shold be included

# %%
# adjust city values for misspellings of san antonio, lowercase all values, and keep only San Antonio data
def fuzzy_sa(value):
    ''' takes in a pandas value and returns san antonio if string is a 90 or higher ratio to san antonio
        otherwise returns lower cased version of the original string'''
    
    value = str(value).lower()
    
    sa1 = 'san antonio'
    sa2 = 'sa'
    
    ratio1 = fuzz.ratio(sa1,value)
    ratio2 = fuzz.ratio(sa2,value)
    
    if (ratio1 >= 80) or (ratio2 >= 60):
        
        return 'san antonio'
    
    else:
        
        return value

df['city'] = df.city.apply(fuzzy_sa)

# remove cities not in list of acceptaple cities
cities = ['san antonio']

df = df[df.city.isin(cities)]

df.head(15)
# Out:
#    case_number  file_date judgement_date disposition_date         city  \
# 0   11E2102330 2021-12-13     2024-09-17       2024-09-17  san antonio
# 1   11E2301639 2023-05-10     2024-05-01       2024-05-01  san antonio
# 2   11E2303045 2023-08-16     2024-01-11       2023-12-08  san antonio
# 3   11E2303045 2023-08-16     2024-01-11       2023-12-08  san antonio
# 4   11E2303297 2023-08-30     2024-02-08       2024-02-08  san antonio
# 5   11E2303925 2023-10-09     2024-01-11       2024-01-11  san antonio
# 6   11E2304048 2023-10-17     2024-01-04       2024-01-04  san antonio
# 7   11E2304072 2023-10-18     2024-07-09       2024-07-09  san antonio
# 8   11E2304114 2023-10-19     2024-01-11       2024-01-11  san antonio
# 9   11E2304258 2023-10-26     2024-06-18       2024-06-18  san antonio
# 10  11E2304278 2023-10-27     2024-01-04       2024-01-04  san antonio
# 11  11E2304289 2023-10-30     2024-01-23       2024-01-23  san antonio
# 12  11E2304298 2023-10-30     2024-02-20       2024-02-20  san antonio
# 13  11E2304327 2023-11-01     2024-01-04       2024-01-04  san antonio
# 14  11E2304368 2023-11-03     2024-01-04       2024-01-04  san antonio
#
#       zip_code                   disposition
# 0        78221  Judgment for Plaintiff (OCA)
# 1        78227        Agreed Judgments (OCA)
# 2        78214                     Dismissed
# 3        78214                     Dismissed
# 4        78251       Default Judgments (OCA)
# 5   78253-4301  Judgment for Plaintiff (OCA)
# 6        78226  Judgment for Plaintiff (OCA)
# 7        78221   Take Nothing Judgment (OCA)
# 8        78221  Judgment for Plaintiff (OCA)
# 9        78214  Judgment for Plaintiff (OCA)
# 10       78211       Default Judgments (OCA)
# 11       78221  Judgment for Plaintiff (OCA)
# 12       78245  Judgment for Plaintiff (OCA)
# 13       78221  Judgment for Plaintiff (OCA)
# 14       78253       Default Judgments (OCA)

# %% [markdown]
# ## Normalizing Data in zip_code to 5 Digit Values
# * Data in some values is presented in 9 digit format while the majority is in 5 digit format

# %%
# get first five digits of values in zip_code column

df['zip_code'] = df.zip_code.apply(lambda x : str(x)[:5])

df.head(15)
# Out:
#    case_number  file_date judgement_date disposition_date         city  \
# 0   11E2102330 2021-12-13     2024-09-17       2024-09-17  san antonio
# 1   11E2301639 2023-05-10     2024-05-01       2024-05-01  san antonio
# 2   11E2303045 2023-08-16     2024-01-11       2023-12-08  san antonio
# 3   11E2303045 2023-08-16     2024-01-11       2023-12-08  san antonio
# 4   11E2303297 2023-08-30     2024-02-08       2024-02-08  san antonio
# 5   11E2303925 2023-10-09     2024-01-11       2024-01-11  san antonio
# 6   11E2304048 2023-10-17     2024-01-04       2024-01-04  san antonio
# 7   11E2304072 2023-10-18     2024-07-09       2024-07-09  san antonio
# 8   11E2304114 2023-10-19     2024-01-11       2024-01-11  san antonio
# 9   11E2304258 2023-10-26     2024-06-18       2024-06-18  san antonio
# 10  11E2304278 2023-10-27     2024-01-04       2024-01-04  san antonio
# 11  11E2304289 2023-10-30     2024-01-23       2024-01-23  san antonio
# 12  11E2304298 2023-10-30     2024-02-20       2024-02-20  san antonio
# 13  11E2304327 2023-11-01     2024-01-04       2024-01-04  san antonio
# 14  11E2304368 2023-11-03     2024-01-04       2024-01-04  san antonio
#
#    zip_code                   disposition
# 0     78221  Judgment for Plaintiff (OCA)
# 1     78227        Agreed Judgments (OCA)
# 2     78214                     Dismissed
# 3     78214                     Dismissed
# 4     78251       Default Judgments (OCA)
# 5     78253  Judgment for Plaintiff (OCA)
# 6     78226  Judgment for Plaintiff (OCA)
# 7     78221   Take Nothing Judgment (OCA)
# 8     78221  Judgment for Plaintiff (OCA)
# 9     78214  Judgment for Plaintiff (OCA)
# 10    78211       Default Judgments (OCA)
# 11    78221  Judgment for Plaintiff (OCA)
# 12    78245  Judgment for Plaintiff (OCA)
# 13    78221  Judgment for Plaintiff (OCA)
# 14    78253       Default Judgments (OCA)

# %% [markdown]
# ## After Dropping Duplicate rows Duplicated Case Numbers Still Exist Due to Differing Dispositions

# %%
df = df.drop_duplicates().reset_index(drop=True)

df[df.case_number == '41E2406496']
# Out:
#       case_number  file_date judgement_date disposition_date         city  \
# 14850  41E2406496 2024-10-24     2024-11-19       2024-11-19  san antonio
# 14851  41E2406496 2024-10-24     2024-11-19       2024-11-08  san antonio
#
#       zip_code                              disposition
# 14850    78219                  Default Judgments (OCA)
# 14851    78219  Dismissed for Want of Prosecution (OCA)

# %% [markdown]
# ## Examening Dismissed Cases

# %%
# add boolean column to identify rows with dismissed in disposition columns
df['dismissed'] = df.disposition.apply(lambda x : 'Dismissed' in x)

# get list of case numbers that were dismissed
dis_df = df[df.dismissed == True]

dismissed = list(set(dis_df.case_number.tolist()))

# %% [markdown]
# ### Non-suited or Dismissed by Plaintiff  and Judgment for Plaintiff Appear on the Same Date
# * File and judgement dates are the same across case numbers
# * Disposition date changes with disposition

# %%
# example 1
df_case = df[df.case_number == dismissed[0]]
df_case
# Out:
#      case_number  file_date judgement_date disposition_date         city  \
# 1800  11E2402950 2024-07-10     2024-07-25       2024-07-25  san antonio
#
#      zip_code                                 disposition  dismissed
# 1800    78251  Non-suited or Dismissed by Plaintiff (OCA)       True

# %%
# example 2
df_case = df[df.case_number == dismissed[11]]
df_case
# Out:
#       case_number  file_date judgement_date disposition_date         city  \
# 13062  41E2402204 2024-04-16     2024-05-28       2024-05-28  san antonio
# 13063  41E2402204 2024-04-16     2024-05-28       2024-05-14  san antonio
#
#       zip_code                              disposition  dismissed
# 13062    78213                  Default Judgments (OCA)      False
# 13063    78213  Dismissed for Want of Prosecution (OCA)       True

# %%
# example 3
df_case = df[df.case_number == dismissed[50]]
df_case
# Out:
#       case_number  file_date judgement_date disposition_date         city  \
# 11254  31E2404123 2024-10-03     2024-11-14       2024-12-06  san antonio
# 11255  31E2404123 2024-10-03     2024-11-14       2024-11-14  san antonio
# 11256  31E2404123 2024-10-03     2024-11-14       2024-10-24  san antonio
#
#       zip_code                              disposition  dismissed
# 11254    78255                                 Appealed      False
# 11255    78255                  Default Judgments (OCA)      False
# 11256    78255  Dismissed for Want of Prosecution (OCA)       True

# %% [markdown]
# ## Eleminating Duplicate Case Numbers
# * Keeping row with oldest disposition date for each case number
# * All duplicate case numbers dropped successfully

# %%
df = df.sort_values(by='disposition_date',ascending=False).reset_index(drop=True)

df = df.drop_duplicates(subset='case_number', keep='first').reset_index(drop=True)

df.head(10)
# Out:
#   case_number  file_date judgement_date disposition_date         city  \
# 0  31E2405002 2024-11-26     2024-12-17       2025-01-10  san antonio
# 1  31E2405011 2024-12-02     2024-12-19       2025-01-10  san antonio
# 2  31E2404980 2024-11-25     2024-12-17       2025-01-10  san antonio
# 3  31E2404897 2024-11-19     2024-12-10       2025-01-07  san antonio
# 4  31E2404217 2024-10-10     2024-10-31       2025-01-06  san antonio
# 5  41E2400487 2024-01-18     2024-02-23       2025-01-03  san antonio
# 6  41E2401335 2024-02-20     2024-05-15       2025-01-03  san antonio
# 7  41E2401557 2024-03-11     2024-04-23       2025-01-03  san antonio
# 8  31E2404641 2024-11-07     2024-12-12       2024-12-27  san antonio
# 9  31E2404660 2024-11-08     2024-12-11       2024-12-27  san antonio
#
#   zip_code                   disposition  dismissed
# 0    78232                      Appealed      False
# 1    78257                      Appealed      False
# 2    78247                      Appealed      False
# 3    78229                      Appealed      False
# 4    78216                      Appealed      False
# 5    78233       Default Judgments (OCA)      False
# 6    78222  Judgment for Plaintiff (OCA)      False
# 7    78220       Default Judgments (OCA)      False
# 8    78213                      Appealed      False
# 9    78232                      Appealed      False

# %% [markdown]
# # Dropping Cases not Likely to Result in Eviction
# * **Likely Eviction**
#     * Default Judgments (OCA)
#     * Judgment for Plaintiff (OCA)
# * **Ambiguous or Likely No Eviction**
#     * Appealed
#     * Take Nothing Judgment (OCA)
#     * Non-suited or Dismissed by Plaintiff (OCA)
#     * Agreed Judgments (OCA)
#     * Dismissed for Want of Prosecution (OCA)
#     * Dismissed
#     * Trial/Hearing by Judge/Hearing Officer (OCA)
#     * Dismissed for Want of Jurisdiction (OCA)

# %%
# removing rows where disposition is not likely to result in eviction
evict = ['Default Judgments (OCA)',
         'Judgment for Plaintiff (OCA)']

df = df[df.disposition.isin(evict)]

df.head(10)
# Out:
#    case_number  file_date judgement_date disposition_date         city  \
# 5   41E2400487 2024-01-18     2024-02-23       2025-01-03  san antonio
# 6   41E2401335 2024-02-20     2024-05-15       2025-01-03  san antonio
# 7   41E2401557 2024-03-11     2024-04-23       2025-01-03  san antonio
# 26  31E2404952 2024-11-21     2024-12-19       2024-12-19  san antonio
# 27  21E2407650 2024-12-09     2024-12-19       2024-12-19  san antonio
# 28  21E2407658 2024-12-09     2024-12-19       2024-12-19  san antonio
# 29  21E2407657 2024-12-09     2024-12-19       2024-12-19  san antonio
# 30  21E2407656 2024-12-09     2024-12-19       2024-12-19  san antonio
# 31  21E2407655 2024-12-09     2024-12-19       2024-12-19  san antonio
# 32  21E2407654 2024-12-09     2024-12-19       2024-12-19  san antonio
#
#    zip_code                   disposition  dismissed
# 5     78233       Default Judgments (OCA)      False
# 6     78222  Judgment for Plaintiff (OCA)      False
# 7     78220       Default Judgments (OCA)      False
# 26    78230       Default Judgments (OCA)      False
# 27    78251       Default Judgments (OCA)      False
# 28    78229  Judgment for Plaintiff (OCA)      False
# 29    78229       Default Judgments (OCA)      False
# 30    78229       Default Judgments (OCA)      False
# 31    78229       Default Judgments (OCA)      False
# 32    78229       Default Judgments (OCA)      False

# %% [markdown]
# ## Dropping Filter Columns

# %%
df = df[['case_number',
         'disposition_date',
         'zip_code']]

# %% [markdown]
# # Full Prep

# %%
def get_prepared_eviction_data():
    '''Prepare eviction data for project'''
    
    # read in unprepared data
    df = pd.read_excel('evictions_2023.xlsx')
    
    # get relevant columns and rename for clarity
    df = df[['CaseNumber',        # used to distinguish unique cases
             'CaseFileDate',      # used for case date
             'JUDGMENT_DT',       # used for date case was ruled on
             'DispositionDate',   # used for date of disposition
             'CITY_NAME',         # used for city location
             'POSTAL_CD',         # used for zip code
             'Disposition',        # used to determine if case was dismissed
             ]]   

    df = df.rename(columns={'CaseNumber'      : 'case_number',
                            'CaseFileDate'    : 'file_date',
                            'JUDGMENT_DT'     : 'judgement_date',
                            'DispositionDate' : 'disposition_date',
                            'CITY_NAME'       : 'city',
                            'POSTAL_CD'       : 'zip_code',
                            'Disposition'     : 'disposition'})
    
    # adjust values in cities for misspellings of san antonio
    df['city'] = df.city.apply(fuzzy_sa)

    # remove cities not in list of acceptaple cities
    cities = ['san antonio']

    df = df[df.city.isin(cities)]

    # get first five digits of values in zip_code column
    df['zip_code'] = df.zip_code.apply(lambda x : str(x)[:5])

    # remove duplicate case numbers keeping the latest according to the disposition date
    df = df.sort_values(by='disposition_date',ascending=False).reset_index(drop=True)

    df = df.drop_duplicates(subset='case_number', keep='first').reset_index(drop=True)
    
    # removing rows where disposition is not likely to result in eviction
    evict = ['Default Judgments (OCA)',
             'Judgment for Plaintiff (OCA)']

    df = df[df.disposition.isin(evict)]
    
    # remove columns used for filtering
    df = df[['case_number',
             'disposition_date',
             'zip_code']].reset_index(drop=True)
    
    df.to_excel('evictions_prepared.xlsx')
    
    return df
    
    
def fuzzy_sa(value):
    ''' takes in a pandas value and returns san antonio if string is a 90 or higher ratio to san antonio
        otherwise returns lower cased version of the original string '''
    
    value = str(value).lower()
    
    sa1 = 'san antonio'
    sa2 = 'sa'
    
    ratio1 = fuzz.ratio(sa1,value)
    ratio2 = fuzz.ratio(sa2,value)
    
    if (ratio1 >= 80) or (ratio2 >= 60):
        
        return 'san antonio'
    
    else:
        
        return value

# %%
df = get_prepared_eviction_data()

# %%
df
# Out:
#       case_number disposition_date zip_code
# 0      41E2400487       2025-01-03    78233
# 1      41E2401335       2025-01-03    78222
# 2      41E2401557       2025-01-03    78220
# 3      31E2404952       2024-12-19    78230
# 4      21E2407650       2024-12-19    78251
# ...           ...              ...      ...
# 13800  31E2304832       2024-01-02    78256
# 13801  31E2304823       2024-01-02    78249
# 13802  31E2304825       2024-01-02    78249
# 13803  31E2304811       2024-01-02    78249
# 13804  31E2304830       2024-01-02    78249
#
# [13805 rows x 3 columns]
